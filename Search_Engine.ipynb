# %% [markdown]
# # 1. Text processing
#
# We will create the pipline of text preprocessing
#
# # 1. 1 Normalization
#
# The first step is normalisation.
# It might include:
# * converting all letters to lower or upper case
# * converting numbers into words or removing numbers
# * removing punctuations, accent marks and other diacritics
# * removing white spaces
# * expanding abbreviations
#
# In this exercise it would be ok to have a lowercase text without specific characters and digits and without unnecessery space symbols.
#
# How neural networks could be implemented for text normalization?

# %%
import re
import nltk
import numpy as np
# normilize text
def normalize(text, query=False):
    text = re.sub("\d+", "", text.lower()) # Lower, no digits
    text = text.replace("_", " ") # Replace _ to space
    text = text.replace("\n", " ")
    if query:
        text = re.sub("[^\w\s*]", " ", text) # No punctuactions except *
        text = re.sub("[^a-z  *]", "", text) # Remove non english letters except *
    else:
        text = re.sub("[^\w\s]", " ", text) # No punctuactions
        text = re.sub("[^a-z ]", "", text) # Remove non english letters
    text = re.sub(' +', ' ', text) # Remove repeated whitespaces
    return text

# %%
text = """Borrowed from Latin per sē (“by itself”), from per (“by, through”) and sē (“itself, himself, herself, themselves”)"""

text = normalize(text)
print(text)
# Out:
# borrowed from latin per s by itself from per by through and s itself himself herself themselves

# %% [markdown]
# # 1.2 Tokenize
# Use nltk tokenizer to tokenize the text

# %%
# tokenize text using nltk lib
def tokenize(text):
    return nltk.word_tokenize(text)

# %%
tokens = tokenize(text)
print(tokens)
# Out:
# ['borrowed', 'from', 'latin', 'per', 's', 'by', 'itself', 'from', 'per', 'by', 'through', 'and', 's', 'itself', 'himself', 'herself', 'themselves']

# %% [markdown]
# # 1.3 Lemmatization
# What is the difference between stemming and lemmatization?
#
# [Optional reading](https://towardsdatascience.com/state-of-the-art-multilingual-lemmatization-f303e8ff1a8)

# %%
def lemmatization(tokens):
    # Lemmatize text using nltk
    lemm = nltk.stem.WordNetLemmatizer()
    return [lemm.lemmatize(token) for token in tokens]

# %%
lemmed = lemmatization(tokens)
print(lemmed)
# Out:
# ['borrowed', 'from', 'latin', 'per', 's', 'by', 'itself', 'from', 'per', 'by', 'through', 'and', 's', 'itself', 'himself', 'herself', 'themselves']

# %% [markdown]
# # 1.4 Stop words
# The next step is to remove stop words. Take the list of stop words from nltk.

# %%
def remove_stop_word(tokens):
    # Remove stopwords with nltk
    return [token for token in tokens if not token in nltk.corpus.stopwords.words('english')]

# %%
clean = remove_stop_word(lemmed)
print(clean)
# Out:
# ['borrowed', 'latin', 'per', 'per']

# %% [markdown]
# # 1.5 Pipeline
# Run a complete pipeline inone function.

# %%
text = """Borrowed from Latin per sē (“by itself”), from per (“by, through”) and sē (“itself, himself, herself, themselves”)"""

def preprocess(text):
    return remove_stop_word(lemmatization(tokenize(normalize(text)))) # All-in-one

# %%
clean = preprocess(text)
print(clean)
# Out:
# ['borrowed', 'latin', 'per', 'per']

# %% [markdown]
# # 2. Collection
#
# Download Reuters data from here:
# https://archive.ics.uci.edu/ml/machine-learning-databases/reuters21578-mld/reuters21578.tar.gz
#
# Read data description here:
# https://archive.ics.uci.edu/ml/datasets/reuters-21578+text+categorization+collection
#
# The function should return a list of strings - raw texts. Remove html tags using bs4 package.

# %% [markdown]
# ## 2.1 Alternative (0.5 task bonus points)
#
# Download songs (the process takes time, 1000 documents might be enough for a sake of exercise) from https://www.lyrics.com/. Implement a text search on it. In this case you have to creare class *Song* with fiels *title*, *artist* *and* text. The collection will contain a list of songs.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
import json
import os
load_dir = "./loads"
lyrics_url = "https://www.lyrics.com/random.php"
error_url = "https://www.lyrics.com/no-lyrics.php"
base_url = "https://www.lyrics.com/lyric/"
n_lyrics = 1000

# Class where we store all songs
class Song:
    def __init__(self, url=None):
        self.url = url
        self.title = None
        self.text = None
        self.artists = None
        success = self.get()
        
    def __str__(self):
        return f"Song {self.title} by {', '.join(self.artists)}"
    
    def __repr__(self):
        return self.__str__()
        
    def __eq__(self, other):
        return self.url == other.url
    
    def __hash__(self):
        return self.title.__hash__()
    
    def get(self):
        # Try to get from the directory, if not - download a random song from the website
        if self.url is None or not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
        print(f"Loaded {self.url}")

    def download(self):
        try:
            # Downloads a random songs from the website
            page = requests.get(lyrics_url)
            
            # Store url
            self.url = page.url
            if page.url == error_url: #If broken url - skip
                return False
            soup = BeautifulSoup(page.content, 'html.parser')
            # Get title
            self.title = soup.find(["h1","h2"], {"id":"lyric-title-text"}).text
            # Get artist name
            artists = soup.find("h3", {"class":"lyric-artist"}).findAll('a')
            self.artists = []
            for artist in artists[:-1]: # The last item is this list is "buy this song" promotions
                self.artists.append(artist.text) 
            # Get song body
            self.text = soup.find("pre", {"class":"lyric-body"}).text.replace("\r","")
        except Exception as e:
            print(e)
            return False
        return True
    
    def persist(self):
        # Try to save the song to ./load_dir/{id}
        if not os.path.exists(load_dir):
            os.mkdir(load_dir)
        file = open(os.path.join(load_dir, self.url[len(base_url):].split("/")[0]), "w")
        js = {"artists-name":self.artists,"song-name":self.title,"song-text":self.text}
        file.write(json.dumps(js))
        file.close()
        return True
    
    def load(self):
        # Try to load file from ./load_dir/{id}
        try:
            file = open(os.path.join(load_dir, self.url[len(base_url):].split("/")[0]), "r")
        except FileNotFoundError as e:
            return False
        js = json.loads(file.read())
        self.title = js["song-name"]
        self.text = js["song-text"]
        self.artists = js['artists-name']
        file.close()
        return True

# %%
def load_lyrics(load_existing=False):
    # loads lyrics
    songs = []
    # If we have some in directory - get them
    if load_existing and os.path.exists(load_dir):
        dir_listing = os.listdir(load_dir)
        for song in dir_listing:
            if len(songs) >= n_lyrics:
                break
            s = Song(base_url+song)
            if s not in songs:
                songs.append(s)
    # Otherwise download the remaining at random
    while len(songs) < n_lyrics:
        try:
            s = Song()
        except FileNotFoundError:
            continue
        if s not in songs:
            songs.append(s)
    return songs
    
    
def get_collection():
    collection = load_lyrics(True)
    return collection

# %%
collection = get_collection()
print(len(collection))
# Out:
# Loaded https://www.lyrics.com/lyric/1021412
# Loaded https://www.lyrics.com/lyric/25292779
# Loaded https://www.lyrics.com/lyric/12964046
# Loaded https://www.lyrics.com/lyric/15108595
# Loaded https://www.lyrics.com/lyric/7576204
# Loaded https://www.lyrics.com/lyric/26570577
# Loaded https://www.lyrics.com/lyric/16839229
# Loaded https://www.lyrics.com/lyric/26905626
# Loaded https://www.lyrics.com/lyric/23638562
# Loaded https://www.lyrics.com/lyric/6933500
# Loaded https://www.lyrics.com/lyric/27127930
# Loaded https://www.lyrics.com/lyric/25017501
# Loaded https://www.lyrics.com/lyric/14306971
# Loaded https://www.lyrics.com/lyric/743122
# Loaded https://www.lyrics.com/lyric/10238917
# Loaded https://www.lyrics.com/lyric/12816111
# Loaded https://www.lyrics.com/lyric/27184017
# Loaded https://www.lyrics.com/lyric/21559417
# Loaded https://www.lyrics.com/lyric/16650429
# Loaded https://www.lyrics.com/lyric/15016155
# Loaded https://www.lyrics.com/lyric/1904658
# Loaded https://www.lyrics.com/lyric/32264362
# Loaded https://www.lyrics.com/lyric/5577900
# Loaded https://www.lyrics.com/lyric/24068219
# Loaded https://www.lyrics.com/lyric/2861383
# Loaded https://www.lyrics.com/lyric/25796949
# Loaded https://www.lyrics.com/lyric/9085175
# Loaded https://www.lyrics.com/lyric/1544553
# Loaded https://www.lyrics.com/lyric/637862
# Loaded https://www.lyrics.com/lyric/13916433
# Loaded https://www.lyrics.com/lyric/8630493
# Loaded https://www.lyrics.com/lyric/8265722
# Loaded https://www.lyrics.com/lyric/30261752
# Loaded https://www.lyrics.com/lyric/23314385
# Loaded https://www.lyrics.com/lyric/15236208
# Loaded https://www.lyrics.com/lyric/32328103
# Loaded https://www.lyrics.com/lyric/31862260
# Loaded https://www.lyrics.com/lyric/11544854
# Loaded https://www.lyrics.com/lyric/14982590
# Loaded https://www.lyrics.com/lyric/15377416
# Loaded https://www.lyrics.com/lyric/11395765
# Loaded https://www.lyrics.com/lyric/32622864
# Loaded https://www.lyrics.com/lyric/32190583
# Loaded https://www.lyrics.com/lyric/6551611
# Loaded https://www.lyrics.com/lyric/9468715
# Loaded https://www.lyrics.com/lyric/10808084
# Loaded https://www.lyrics.com/lyric/16695297
# Loaded https://www.lyrics.com/lyric/7187380
# Loaded https://www.lyrics.com/lyric/7772851
# Loaded https://www.lyrics.com/lyric/31833893
# Loaded https://www.lyrics.com/lyric/15802097
# Loaded https://www.lyrics.com/lyric/11086269
# Loaded https://www.lyrics.com/lyric/10680317
# Loaded https://www.lyrics.com/lyric/13745039
# Loaded https://www.lyrics.com/lyric/17057071
# Loaded https://www.lyrics.com/lyric/1638872
# Loaded https://www.lyrics.com/lyric/6173172
# Loaded https://www.lyrics.com/lyric/16502691
# Loaded https://www.lyrics.com/lyric/4784479
# Loaded https://www.lyrics.com/lyric/8222297
# Loaded https://www.lyrics.com/lyric/2437352
# Loaded https://www.lyrics.com/lyric/13652046
# Loaded https://www.lyrics.com/lyric/7582374
# Loaded https://www.lyrics.com/lyric/9355540
# Loaded https://www.lyrics.com/lyric/27247769
# Loaded https://www.lyrics.com/lyric/31583074
# Loaded https://www.lyrics.com/lyric/9925408
# Loaded https://www.lyrics.com/lyric/15812227
# Loaded https://www.lyrics.com/lyric/13887607
# Loaded https://www.lyrics.com/lyric/10267828
# Loaded https://www.lyrics.com/lyric/29817137
# Loaded https://www.lyrics.com/lyric/28243590
# Loaded https://www.lyrics.com/lyric/8339131
# Loaded https://www.lyrics.com/lyric/13517381
# Loaded https://www.lyrics.com/lyric/1563914
# Loaded https://www.lyrics.com/lyric/19297261
# Loaded https://www.lyrics.com/lyric/17745945
# Loaded https://www.lyrics.com/lyric/27214012
# Loaded https://www.lyrics.com/lyric/18395083
# Loaded https://www.lyrics.com/lyric/28165738
# Loaded https://www.lyrics.com/lyric/5449009
# Loaded https://www.lyrics.com/lyric/6710126
# Loaded https://www.lyrics.com/lyric/26900483
# Loaded https://www.lyrics.com/lyric/12743440
# Loaded https://www.lyrics.com/lyric/32545357
# Loaded https://www.lyrics.com/lyric/11992177
# Loaded https://www.lyrics.com/lyric/11921446
# Loaded https://www.lyrics.com/lyric/4867357
# Loaded https://www.lyrics.com/lyric/32026276
# Loaded https://www.lyrics.com/lyric/11888334
# Loaded https://www.lyrics.com/lyric/18879580
# Loaded https://www.lyrics.com/lyric/17629516
# Loaded https://www.lyrics.com/lyric/12472879
# Loaded https://www.lyrics.com/lyric/30639402
# Loaded https://www.lyrics.com/lyric/20194528
# Loaded https://www.lyrics.com/lyric/32381363
# Loaded https://www.lyrics.com/lyric/6093497
# Loaded https://www.lyrics.com/lyric/23161092
# Loaded https://www.lyrics.com/lyric/8409108
# Loaded https://www.lyrics.com/lyric/25074964
# Loaded https://www.lyrics.com/lyric/19204042
# Loaded https://www.lyrics.com/lyric/18031100
# Loaded https://www.lyrics.com/lyric/17835984
# Loaded https://www.lyrics.com/lyric/17002948
# Loaded https://www.lyrics.com/lyric/11877122
# Loaded https://www.lyrics.com/lyric/12792258
# Loaded https://www.lyrics.com/lyric/9515104
# Loaded https://www.lyrics.com/lyric/5750203
# Loaded https://www.lyrics.com/lyric/826691
# Loaded https://www.lyrics.com/lyric/2610927
# Loaded https://www.lyrics.com/lyric/26838795
# Loaded https://www.lyrics.com/lyric/2612775
# Loaded https://www.lyrics.com/lyric/23438158
# Loaded https://www.lyrics.com/lyric/13256461
# Loaded https://www.lyrics.com/lyric/20072110
# Loaded https://www.lyrics.com/lyric/9362476
# Loaded https://www.lyrics.com/lyric/17676846
# Loaded https://www.lyrics.com/lyric/5840912
# Loaded https://www.lyrics.com/lyric/10820824
# Loaded https://www.lyrics.com/lyric/28700141
# Loaded https://www.lyrics.com/lyric/25662971
# Loaded https://www.lyrics.com/lyric/11001381
# Loaded https://www.lyrics.com/lyric/22222317
# Loaded https://www.lyrics.com/lyric/16867606
# Loaded https://www.lyrics.com/lyric/14803234
# Loaded https://www.lyrics.com/lyric/1309393
# Loaded https://www.lyrics.com/lyric/13519723
# Loaded https://www.lyrics.com/lyric/22971779
# Loaded https://www.lyrics.com/lyric/8818034
# Loaded https://www.lyrics.com/lyric/9498734
# Loaded https://www.lyrics.com/lyric/2459415
# Loaded https://www.lyrics.com/lyric/5006603
# Loaded https://www.lyrics.com/lyric/20896352
# Loaded https://www.lyrics.com/lyric/31721987
# Loaded https://www.lyrics.com/lyric/11394545
# Loaded https://www.lyrics.com/lyric/8612113
# Loaded https://www.lyrics.com/lyric/16516188
# Loaded https://www.lyrics.com/lyric/14506264
# Loaded https://www.lyrics.com/lyric/15878937
# Loaded https://www.lyrics.com/lyric/26990410
# Loaded https://www.lyrics.com/lyric/17693165
# Loaded https://www.lyrics.com/lyric/1150571
# Loaded https://www.lyrics.com/lyric/26276845
# Loaded https://www.lyrics.com/lyric/13840334
# Loaded https://www.lyrics.com/lyric/8794179
# Loaded https://www.lyrics.com/lyric/22227747
# Loaded https://www.lyrics.com/lyric/25410311
# Loaded https://www.lyrics.com/lyric/9239168
# Loaded https://www.lyrics.com/lyric/2238734
# Loaded https://www.lyrics.com/lyric/19043575
# Loaded https://www.lyrics.com/lyric/10589038
# Loaded https://www.lyrics.com/lyric/30004445
# Loaded https://www.lyrics.com/lyric/12180447
# Loaded https://www.lyrics.com/lyric/29546441
# Loaded https://www.lyrics.com/lyric/31250090
# Loaded https://www.lyrics.com/lyric/4263043
# Loaded https://www.lyrics.com/lyric/5467595
# Loaded https://www.lyrics.com/lyric/28193461
# Loaded https://www.lyrics.com/lyric/31127304
# Loaded https://www.lyrics.com/lyric/601694
# Loaded https://www.lyrics.com/lyric/5123660
# Loaded https://www.lyrics.com/lyric/31133477
# Loaded https://www.lyrics.com/lyric/2266102
# Loaded https://www.lyrics.com/lyric/15803777
# Loaded https://www.lyrics.com/lyric/11716704
# Loaded https://www.lyrics.com/lyric/14350991
# Loaded https://www.lyrics.com/lyric/25312678
# Loaded https://www.lyrics.com/lyric/19677330
# Loaded https://www.lyrics.com/lyric/11772178
# Loaded https://www.lyrics.com/lyric/15703466
# Loaded https://www.lyrics.com/lyric/24302195
# Loaded https://www.lyrics.com/lyric/24328673
# Loaded https://www.lyrics.com/lyric/22346206
# Loaded https://www.lyrics.com/lyric/4595581
# Loaded https://www.lyrics.com/lyric/7943635
# Loaded https://www.lyrics.com/lyric/21663434
# Loaded https://www.lyrics.com/lyric/13769335
# Loaded https://www.lyrics.com/lyric/11911358
# Loaded https://www.lyrics.com/lyric/2242118
# Loaded https://www.lyrics.com/lyric/5332169
# Loaded https://www.lyrics.com/lyric/10841730
# Loaded https://www.lyrics.com/lyric/10304149
# Loaded https://www.lyrics.com/lyric/20284640
# Loaded https://www.lyrics.com/lyric/2382095
# Loaded https://www.lyrics.com/lyric/10973466
# Loaded https://www.lyrics.com/lyric/16460483
# Loaded https://www.lyrics.com/lyric/19198998
# Loaded https://www.lyrics.com/lyric/22984159
# Loaded https://www.lyrics.com/lyric/648219
# Loaded https://www.lyrics.com/lyric/30665277
# Loaded https://www.lyrics.com/lyric/11914678
# Loaded https://www.lyrics.com/lyric/19780939
# Loaded https://www.lyrics.com/lyric/15238165
# Loaded https://www.lyrics.com/lyric/27186828
# Loaded https://www.lyrics.com/lyric/11483751
# Loaded https://www.lyrics.com/lyric/7068244
# Loaded https://www.lyrics.com/lyric/2122532
# Loaded https://www.lyrics.com/lyric/912747
# Loaded https://www.lyrics.com/lyric/24865109
# Loaded https://www.lyrics.com/lyric/28213146
# Loaded https://www.lyrics.com/lyric/14020711
# Loaded https://www.lyrics.com/lyric/8849648
# Loaded https://www.lyrics.com/lyric/24655385
# Loaded https://www.lyrics.com/lyric/26183010
# Loaded https://www.lyrics.com/lyric/7328744
# Loaded https://www.lyrics.com/lyric/1678473
# Loaded https://www.lyrics.com/lyric/194478
# Loaded https://www.lyrics.com/lyric/28154350
# Loaded https://www.lyrics.com/lyric/17760899
# Loaded https://www.lyrics.com/lyric/3533951
# Loaded https://www.lyrics.com/lyric/16122439
# Loaded https://www.lyrics.com/lyric/30336237
# Loaded https://www.lyrics.com/lyric/29890940
# Loaded https://www.lyrics.com/lyric/6776296
# Loaded https://www.lyrics.com/lyric/172455
# Loaded https://www.lyrics.com/lyric/5022806
# Loaded https://www.lyrics.com/lyric/7059858
# Loaded https://www.lyrics.com/lyric/81596
# Loaded https://www.lyrics.com/lyric/14957995
# Loaded https://www.lyrics.com/lyric/4063636
# Loaded https://www.lyrics.com/lyric/25073836
# Loaded https://www.lyrics.com/lyric/24876468
# Loaded https://www.lyrics.com/lyric/1029096
# Loaded https://www.lyrics.com/lyric/27020025
# Loaded https://www.lyrics.com/lyric/27959915
# Loaded https://www.lyrics.com/lyric/5733159
# Loaded https://www.lyrics.com/lyric/29273498
# Loaded https://www.lyrics.com/lyric/22885259
# Loaded https://www.lyrics.com/lyric/3922392
# Loaded https://www.lyrics.com/lyric/23720377
# Loaded https://www.lyrics.com/lyric/3336795
# Loaded https://www.lyrics.com/lyric/31039763
# Loaded https://www.lyrics.com/lyric/30472798
# Loaded https://www.lyrics.com/lyric/31643706
# Loaded https://www.lyrics.com/lyric/1357164
# Loaded https://www.lyrics.com/lyric/12283771
# Loaded https://www.lyrics.com/lyric/24763393
# Loaded https://www.lyrics.com/lyric/1432106
# Loaded https://www.lyrics.com/lyric/9251768
# Loaded https://www.lyrics.com/lyric/2167731
# Loaded https://www.lyrics.com/lyric/31937889
# Loaded https://www.lyrics.com/lyric/11873279
# Loaded https://www.lyrics.com/lyric/15571561
# Loaded https://www.lyrics.com/lyric/14522377
# Loaded https://www.lyrics.com/lyric/3460595
# Loaded https://www.lyrics.com/lyric/9007988
# Loaded https://www.lyrics.com/lyric/24836035
# Loaded https://www.lyrics.com/lyric/23827438
# Loaded https://www.lyrics.com/lyric/18732124
# Loaded https://www.lyrics.com/lyric/15811010
# Loaded https://www.lyrics.com/lyric/3909604
# Loaded https://www.lyrics.com/lyric/32682244
# Loaded https://www.lyrics.com/lyric/5141392
# Loaded https://www.lyrics.com/lyric/6647749
# Loaded https://www.lyrics.com/lyric/7110418
# Loaded https://www.lyrics.com/lyric/14670063
# Loaded https://www.lyrics.com/lyric/30692663
# Loaded https://www.lyrics.com/lyric/4594875
# Loaded https://www.lyrics.com/lyric/564705
# Loaded https://www.lyrics.com/lyric/30444044
# Loaded https://www.lyrics.com/lyric/20840135
# Loaded https://www.lyrics.com/lyric/10221694
# Loaded https://www.lyrics.com/lyric/5824264
# Loaded https://www.lyrics.com/lyric/4212584
# Loaded https://www.lyrics.com/lyric/10063859
# Loaded https://www.lyrics.com/lyric/10464531
# Loaded https://www.lyrics.com/lyric/23706432
# Loaded https://www.lyrics.com/lyric/4043826
# Loaded https://www.lyrics.com/lyric/2800929
# Loaded https://www.lyrics.com/lyric/13008397
# Loaded https://www.lyrics.com/lyric/12947806
# Loaded https://www.lyrics.com/lyric/10550688
# Loaded https://www.lyrics.com/lyric/7480259
# Loaded https://www.lyrics.com/lyric/6523443
# Loaded https://www.lyrics.com/lyric/9825371
# Loaded https://www.lyrics.com/lyric/2072233
# Loaded https://www.lyrics.com/lyric/7796772
# Loaded https://www.lyrics.com/lyric/4144704
# Loaded https://www.lyrics.com/lyric/921208
# Loaded https://www.lyrics.com/lyric/89669
# Loaded https://www.lyrics.com/lyric/3427169
# Loaded https://www.lyrics.com/lyric/1034756
# Loaded https://www.lyrics.com/lyric/17792173
# Loaded https://www.lyrics.com/lyric/116220
# Loaded https://www.lyrics.com/lyric/1306887
# Loaded https://www.lyrics.com/lyric/31666427
# Loaded https://www.lyrics.com/lyric/8564510
# Loaded https://www.lyrics.com/lyric/2198323
# Loaded https://www.lyrics.com/lyric/22043023
# Loaded https://www.lyrics.com/lyric/4077794
# Loaded https://www.lyrics.com/lyric/23762815
# Loaded https://www.lyrics.com/lyric/3935783
# Loaded https://www.lyrics.com/lyric/19740355
# Loaded https://www.lyrics.com/lyric/13248129
# Loaded https://www.lyrics.com/lyric/18992978
# Loaded https://www.lyrics.com/lyric/15492120
# Loaded https://www.lyrics.com/lyric/17867520
# Loaded https://www.lyrics.com/lyric/29169181
# Loaded https://www.lyrics.com/lyric/26911661
# Loaded https://www.lyrics.com/lyric/781056
# Loaded https://www.lyrics.com/lyric/20598857
# Loaded https://www.lyrics.com/lyric/16258201
# Loaded https://www.lyrics.com/lyric/25010876
# Loaded https://www.lyrics.com/lyric/7743118
# Loaded https://www.lyrics.com/lyric/17454838
# Loaded https://www.lyrics.com/lyric/31166988
# Loaded https://www.lyrics.com/lyric/29874956
# Loaded https://www.lyrics.com/lyric/525761
# Loaded https://www.lyrics.com/lyric/15233198
# Loaded https://www.lyrics.com/lyric/13476954
# Loaded https://www.lyrics.com/lyric/21965229
# Loaded https://www.lyrics.com/lyric/19249602
# Loaded https://www.lyrics.com/lyric/7173328
# Loaded https://www.lyrics.com/lyric/681152
# Loaded https://www.lyrics.com/lyric/7867803
# Loaded https://www.lyrics.com/lyric/30072889
# Loaded https://www.lyrics.com/lyric/31550837
# Loaded https://www.lyrics.com/lyric/29853309
# Loaded https://www.lyrics.com/lyric/29596640
# Loaded https://www.lyrics.com/lyric/21226262
# Loaded https://www.lyrics.com/lyric/31988632
# Loaded https://www.lyrics.com/lyric/16101911
# Loaded https://www.lyrics.com/lyric/3689996
# Loaded https://www.lyrics.com/lyric/17986362
# Loaded https://www.lyrics.com/lyric/29645895
# Loaded https://www.lyrics.com/lyric/3036142
# Loaded https://www.lyrics.com/lyric/27341514
# Loaded https://www.lyrics.com/lyric/22459222
# Loaded https://www.lyrics.com/lyric/19764099
# Loaded https://www.lyrics.com/lyric/5134862
# Loaded https://www.lyrics.com/lyric/19258757
# Loaded https://www.lyrics.com/lyric/25282292
# Loaded https://www.lyrics.com/lyric/1711196
# Loaded https://www.lyrics.com/lyric/17592622
# Loaded https://www.lyrics.com/lyric/8112291
# Loaded https://www.lyrics.com/lyric/31624997
# Loaded https://www.lyrics.com/lyric/20984991
# Loaded https://www.lyrics.com/lyric/32442066
# Loaded https://www.lyrics.com/lyric/6686421
# Loaded https://www.lyrics.com/lyric/9267023
# Loaded https://www.lyrics.com/lyric/28337357
# Loaded https://www.lyrics.com/lyric/15686649
# Loaded https://www.lyrics.com/lyric/20048442
# Loaded https://www.lyrics.com/lyric/4707645
# Loaded https://www.lyrics.com/lyric/10950311
# Loaded https://www.lyrics.com/lyric/25667701
# Loaded https://www.lyrics.com/lyric/6029648
# Loaded https://www.lyrics.com/lyric/24869368
# Loaded https://www.lyrics.com/lyric/16413655
# Loaded https://www.lyrics.com/lyric/1989855
# Loaded https://www.lyrics.com/lyric/28089025
# Loaded https://www.lyrics.com/lyric/23754101
# Loaded https://www.lyrics.com/lyric/9795261
# Loaded https://www.lyrics.com/lyric/31597421
# Loaded https://www.lyrics.com/lyric/18951123
# Loaded https://www.lyrics.com/lyric/23081593
# Loaded https://www.lyrics.com/lyric/29982615
# Loaded https://www.lyrics.com/lyric/32702126
# Loaded https://www.lyrics.com/lyric/7489152
# Loaded https://www.lyrics.com/lyric/3997530
# Loaded https://www.lyrics.com/lyric/29064731
# Loaded https://www.lyrics.com/lyric/14283301
# Loaded https://www.lyrics.com/lyric/24350345
# Loaded https://www.lyrics.com/lyric/362577
# Loaded https://www.lyrics.com/lyric/29663430
# Loaded https://www.lyrics.com/lyric/19661395
# Loaded https://www.lyrics.com/lyric/18877827
# Loaded https://www.lyrics.com/lyric/558091
# Loaded https://www.lyrics.com/lyric/14278084
# Loaded https://www.lyrics.com/lyric/2824588
# Loaded https://www.lyrics.com/lyric/635495
# Loaded https://www.lyrics.com/lyric/16015269
# Loaded https://www.lyrics.com/lyric/30882887
# Loaded https://www.lyrics.com/lyric/12784215
# Loaded https://www.lyrics.com/lyric/6927930
# Loaded https://www.lyrics.com/lyric/25391401
# Loaded https://www.lyrics.com/lyric/17283234
# Loaded https://www.lyrics.com/lyric/2568397
# Loaded https://www.lyrics.com/lyric/14040882
# Loaded https://www.lyrics.com/lyric/195469
# Loaded https://www.lyrics.com/lyric/31885606
# Loaded https://www.lyrics.com/lyric/27182565
# Loaded https://www.lyrics.com/lyric/3695271
# Loaded https://www.lyrics.com/lyric/5277538
# Loaded https://www.lyrics.com/lyric/14418498
# Loaded https://www.lyrics.com/lyric/17689489
# Loaded https://www.lyrics.com/lyric/2411267
# Loaded https://www.lyrics.com/lyric/28041489
# Loaded https://www.lyrics.com/lyric/29342055
# Loaded https://www.lyrics.com/lyric/15386632
# Loaded https://www.lyrics.com/lyric/31126319
# Loaded https://www.lyrics.com/lyric/26172138
# Loaded https://www.lyrics.com/lyric/12379266
# Loaded https://www.lyrics.com/lyric/31192519
# Loaded https://www.lyrics.com/lyric/24854701
# Loaded https://www.lyrics.com/lyric/13784689
# Loaded https://www.lyrics.com/lyric/3006408
# Loaded https://www.lyrics.com/lyric/14239817
# Loaded https://www.lyrics.com/lyric/10854039
# Loaded https://www.lyrics.com/lyric/23029404
# Loaded https://www.lyrics.com/lyric/30008711
# Loaded https://www.lyrics.com/lyric/13667986
# Loaded https://www.lyrics.com/lyric/12254136
# Loaded https://www.lyrics.com/lyric/19515311
# Loaded https://www.lyrics.com/lyric/12288149
# Loaded https://www.lyrics.com/lyric/29837693
# Loaded https://www.lyrics.com/lyric/29498142
# Loaded https://www.lyrics.com/lyric/13879600
# Loaded https://www.lyrics.com/lyric/16985037
# Loaded https://www.lyrics.com/lyric/20214431
# Loaded https://www.lyrics.com/lyric/18466957
# Loaded https://www.lyrics.com/lyric/14739348
# Loaded https://www.lyrics.com/lyric/15570986
# Loaded https://www.lyrics.com/lyric/9305153
# Loaded https://www.lyrics.com/lyric/10477099
# Loaded https://www.lyrics.com/lyric/19492779
# Loaded https://www.lyrics.com/lyric/6987506
# Loaded https://www.lyrics.com/lyric/28004600
# Loaded https://www.lyrics.com/lyric/32349034
# Loaded https://www.lyrics.com/lyric/22706435
# Loaded https://www.lyrics.com/lyric/18053528
# Loaded https://www.lyrics.com/lyric/3479958
# Loaded https://www.lyrics.com/lyric/2370896
# Loaded https://www.lyrics.com/lyric/28669972
# Loaded https://www.lyrics.com/lyric/31340517
# Loaded https://www.lyrics.com/lyric/14930601
# Loaded https://www.lyrics.com/lyric/19410783
# Loaded https://www.lyrics.com/lyric/2625392
# Loaded https://www.lyrics.com/lyric/23078906
# Loaded https://www.lyrics.com/lyric/32219822
# Loaded https://www.lyrics.com/lyric/21076175
# Loaded https://www.lyrics.com/lyric/25819778
# Loaded https://www.lyrics.com/lyric/20558410
# Loaded https://www.lyrics.com/lyric/16504604
# Loaded https://www.lyrics.com/lyric/20689261
# Loaded https://www.lyrics.com/lyric/7714220
# Loaded https://www.lyrics.com/lyric/29555632
# Loaded https://www.lyrics.com/lyric/30560687
# Loaded https://www.lyrics.com/lyric/6439827
# Loaded https://www.lyrics.com/lyric/28129766
# Loaded https://www.lyrics.com/lyric/3064033
# Loaded https://www.lyrics.com/lyric/29299595
# Loaded https://www.lyrics.com/lyric/10756277
# Loaded https://www.lyrics.com/lyric/1271234
# Loaded https://www.lyrics.com/lyric/13910432
# Loaded https://www.lyrics.com/lyric/13880908
# Loaded https://www.lyrics.com/lyric/11650250
# Loaded https://www.lyrics.com/lyric/26335439
# Loaded https://www.lyrics.com/lyric/13476173
# Loaded https://www.lyrics.com/lyric/1993990
# Loaded https://www.lyrics.com/lyric/21144554
# Loaded https://www.lyrics.com/lyric/19371172
# Loaded https://www.lyrics.com/lyric/4976034
# Loaded https://www.lyrics.com/lyric/20358151
# Loaded https://www.lyrics.com/lyric/21137692
# Loaded https://www.lyrics.com/lyric/28381275
# Loaded https://www.lyrics.com/lyric/3254009
# Loaded https://www.lyrics.com/lyric/14126255
# Loaded https://www.lyrics.com/lyric/21092192
# Loaded https://www.lyrics.com/lyric/13502848
# Loaded https://www.lyrics.com/lyric/27158536
# Loaded https://www.lyrics.com/lyric/17902345
# Loaded https://www.lyrics.com/lyric/23172098
# Loaded https://www.lyrics.com/lyric/1189698
# Loaded https://www.lyrics.com/lyric/12592924
# Loaded https://www.lyrics.com/lyric/23069619
# Loaded https://www.lyrics.com/lyric/12707044
# Loaded https://www.lyrics.com/lyric/11924429
# Loaded https://www.lyrics.com/lyric/12293165
# Loaded https://www.lyrics.com/lyric/13092758
# Loaded https://www.lyrics.com/lyric/142644
# Loaded https://www.lyrics.com/lyric/31965917
# Loaded https://www.lyrics.com/lyric/22916290
# Loaded https://www.lyrics.com/lyric/4985692
# Loaded https://www.lyrics.com/lyric/2288600
# Loaded https://www.lyrics.com/lyric/12079926
# Loaded https://www.lyrics.com/lyric/8999228
# Loaded https://www.lyrics.com/lyric/1463877
# Loaded https://www.lyrics.com/lyric/30137722
# Loaded https://www.lyrics.com/lyric/8991414
# Loaded https://www.lyrics.com/lyric/14701887
# Loaded https://www.lyrics.com/lyric/29048053
# Loaded https://www.lyrics.com/lyric/29044877
# Loaded https://www.lyrics.com/lyric/16675541
# Loaded https://www.lyrics.com/lyric/10686740
# Loaded https://www.lyrics.com/lyric/10574815
# Loaded https://www.lyrics.com/lyric/5183081
# Loaded https://www.lyrics.com/lyric/13364243
# Loaded https://www.lyrics.com/lyric/12927364
# Loaded https://www.lyrics.com/lyric/7612987
# Loaded https://www.lyrics.com/lyric/10072725
# Loaded https://www.lyrics.com/lyric/20932184
# Loaded https://www.lyrics.com/lyric/26809679
# Loaded https://www.lyrics.com/lyric/6374000
# Loaded https://www.lyrics.com/lyric/16275879
# Loaded https://www.lyrics.com/lyric/29583147
# Loaded https://www.lyrics.com/lyric/18215067
# Loaded https://www.lyrics.com/lyric/12997491
# Loaded https://www.lyrics.com/lyric/26882893
# Loaded https://www.lyrics.com/lyric/27283515
# Loaded https://www.lyrics.com/lyric/23726812
# Loaded https://www.lyrics.com/lyric/23136921
# Loaded https://www.lyrics.com/lyric/1501024
# Loaded https://www.lyrics.com/lyric/22464834
# Loaded https://www.lyrics.com/lyric/26199253
# Loaded https://www.lyrics.com/lyric/15405240
# Loaded https://www.lyrics.com/lyric/10867129
# Loaded https://www.lyrics.com/lyric/15023732
# Loaded https://www.lyrics.com/lyric/12308535
# Loaded https://www.lyrics.com/lyric/1181068
# Loaded https://www.lyrics.com/lyric/29699945
# Loaded https://www.lyrics.com/lyric/14829883
# Loaded https://www.lyrics.com/lyric/7727936
# Loaded https://www.lyrics.com/lyric/11368477
# Loaded https://www.lyrics.com/lyric/19946540
# Loaded https://www.lyrics.com/lyric/19611889
# Loaded https://www.lyrics.com/lyric/25515916
# Loaded https://www.lyrics.com/lyric/23672387
# Loaded https://www.lyrics.com/lyric/31343015
# Loaded https://www.lyrics.com/lyric/24904651
# Loaded https://www.lyrics.com/lyric/24091551
# Loaded https://www.lyrics.com/lyric/5863405
# Loaded https://www.lyrics.com/lyric/4440190
# Loaded https://www.lyrics.com/lyric/30071037
# Loaded https://www.lyrics.com/lyric/31509645
# Loaded https://www.lyrics.com/lyric/22060377
# Loaded https://www.lyrics.com/lyric/15942724
# Loaded https://www.lyrics.com/lyric/21174437
# Loaded https://www.lyrics.com/lyric/793643
# Loaded https://www.lyrics.com/lyric/2616745
# Loaded https://www.lyrics.com/lyric/771037
# Loaded https://www.lyrics.com/lyric/9370539
# Loaded https://www.lyrics.com/lyric/30122773
# Loaded https://www.lyrics.com/lyric/30304359
# Loaded https://www.lyrics.com/lyric/19250029
# Loaded https://www.lyrics.com/lyric/31938113
# Loaded https://www.lyrics.com/lyric/14489234
# Loaded https://www.lyrics.com/lyric/9684714
# Loaded https://www.lyrics.com/lyric/29935870
# Loaded https://www.lyrics.com/lyric/13920355
# Loaded https://www.lyrics.com/lyric/24364457
# Loaded https://www.lyrics.com/lyric/31695229
# Loaded https://www.lyrics.com/lyric/24892498
# Loaded https://www.lyrics.com/lyric/17682877
# Loaded https://www.lyrics.com/lyric/24851899
# Loaded https://www.lyrics.com/lyric/8958849
# Loaded https://www.lyrics.com/lyric/21580597
# Loaded https://www.lyrics.com/lyric/17793725
# Loaded https://www.lyrics.com/lyric/19784184
# Loaded https://www.lyrics.com/lyric/4807440
# Loaded https://www.lyrics.com/lyric/16419235
# Loaded https://www.lyrics.com/lyric/26875535
# Loaded https://www.lyrics.com/lyric/25093381
# Loaded https://www.lyrics.com/lyric/740988
# Loaded https://www.lyrics.com/lyric/32100691
# Loaded https://www.lyrics.com/lyric/13870792
# Loaded https://www.lyrics.com/lyric/21909084
# Loaded https://www.lyrics.com/lyric/17334028
# Loaded https://www.lyrics.com/lyric/26618305
# Loaded https://www.lyrics.com/lyric/25962661
# Loaded https://www.lyrics.com/lyric/20405671
# Loaded https://www.lyrics.com/lyric/26669216
# Loaded https://www.lyrics.com/lyric/22305844
# Loaded https://www.lyrics.com/lyric/23788741
# Loaded https://www.lyrics.com/lyric/17511140
# Loaded https://www.lyrics.com/lyric/22892475
# Loaded https://www.lyrics.com/lyric/22572354
# Loaded https://www.lyrics.com/lyric/31250256
# Loaded https://www.lyrics.com/lyric/2018666
# Loaded https://www.lyrics.com/lyric/5763929
# Loaded https://www.lyrics.com/lyric/8654710
# Loaded https://www.lyrics.com/lyric/5673270
# Loaded https://www.lyrics.com/lyric/32564987
# Loaded https://www.lyrics.com/lyric/19074455
# Loaded https://www.lyrics.com/lyric/7837053
# Loaded https://www.lyrics.com/lyric/31883680
# Loaded https://www.lyrics.com/lyric/16369330
# Loaded https://www.lyrics.com/lyric/26263034
# Loaded https://www.lyrics.com/lyric/7541133
# Loaded https://www.lyrics.com/lyric/24522431
# Loaded https://www.lyrics.com/lyric/24574000
# Loaded https://www.lyrics.com/lyric/11091812
# Loaded https://www.lyrics.com/lyric/10209232
# Loaded https://www.lyrics.com/lyric/17853993
# Loaded https://www.lyrics.com/lyric/15430853
# Loaded https://www.lyrics.com/lyric/17801793
# Loaded https://www.lyrics.com/lyric/834840
# Loaded https://www.lyrics.com/lyric/24491061
# Loaded https://www.lyrics.com/lyric/20121797
# Loaded https://www.lyrics.com/lyric/4114065
# Loaded https://www.lyrics.com/lyric/9613126
# Loaded https://www.lyrics.com/lyric/22806210
# Loaded https://www.lyrics.com/lyric/19516896
# Loaded https://www.lyrics.com/lyric/8369133
# Loaded https://www.lyrics.com/lyric/29234446
# Loaded https://www.lyrics.com/lyric/8108726
# Loaded https://www.lyrics.com/lyric/9107523
# Loaded https://www.lyrics.com/lyric/11287266
# Loaded https://www.lyrics.com/lyric/18844177
# Loaded https://www.lyrics.com/lyric/31022315
# Loaded https://www.lyrics.com/lyric/25894332
# Loaded https://www.lyrics.com/lyric/25015466
# Loaded https://www.lyrics.com/lyric/22842675
# Loaded https://www.lyrics.com/lyric/24395783
# Loaded https://www.lyrics.com/lyric/30193843
# Loaded https://www.lyrics.com/lyric/16177653
# Loaded https://www.lyrics.com/lyric/1390632
# Loaded https://www.lyrics.com/lyric/165682
# Loaded https://www.lyrics.com/lyric/6899616
# Loaded https://www.lyrics.com/lyric/944347
# Loaded https://www.lyrics.com/lyric/20063801
# Loaded https://www.lyrics.com/lyric/23019201
# Loaded https://www.lyrics.com/lyric/986586
# Loaded https://www.lyrics.com/lyric/21082979
# Loaded https://www.lyrics.com/lyric/11006730
# Loaded https://www.lyrics.com/lyric/10405777
# Loaded https://www.lyrics.com/lyric/2045185
# Loaded https://www.lyrics.com/lyric/26700770
# Loaded https://www.lyrics.com/lyric/10325347
# Loaded https://www.lyrics.com/lyric/13864985
# Loaded https://www.lyrics.com/lyric/23677501
# Loaded https://www.lyrics.com/lyric/14149098
# Loaded https://www.lyrics.com/lyric/11651093
# Loaded https://www.lyrics.com/lyric/28522298
# Loaded https://www.lyrics.com/lyric/23370625
# Loaded https://www.lyrics.com/lyric/13737777
# Loaded https://www.lyrics.com/lyric/3254547
# Loaded https://www.lyrics.com/lyric/5309991
# Loaded https://www.lyrics.com/lyric/4457682
# Loaded https://www.lyrics.com/lyric/11315884
# Loaded https://www.lyrics.com/lyric/30079982
# Loaded https://www.lyrics.com/lyric/26459705
# Loaded https://www.lyrics.com/lyric/103737
# Loaded https://www.lyrics.com/lyric/9499419
# Loaded https://www.lyrics.com/lyric/15708751
# Loaded https://www.lyrics.com/lyric/12979178
# Loaded https://www.lyrics.com/lyric/32046847
# Loaded https://www.lyrics.com/lyric/6580059
# Loaded https://www.lyrics.com/lyric/8111611
# Loaded https://www.lyrics.com/lyric/7438879
# Loaded https://www.lyrics.com/lyric/10006615
# Loaded https://www.lyrics.com/lyric/24624937
# Loaded https://www.lyrics.com/lyric/16449185
# Loaded https://www.lyrics.com/lyric/27698704
# Loaded https://www.lyrics.com/lyric/16975185
# Loaded https://www.lyrics.com/lyric/3375043
# Loaded https://www.lyrics.com/lyric/32215047
# Loaded https://www.lyrics.com/lyric/6464039
# Loaded https://www.lyrics.com/lyric/17500907
# Loaded https://www.lyrics.com/lyric/2294134
# Loaded https://www.lyrics.com/lyric/29658401
# Loaded https://www.lyrics.com/lyric/3300475
# Loaded https://www.lyrics.com/lyric/22241715
# Loaded https://www.lyrics.com/lyric/19129928
# Loaded https://www.lyrics.com/lyric/31649416
# Loaded https://www.lyrics.com/lyric/12411757
# Loaded https://www.lyrics.com/lyric/17424670
# Loaded https://www.lyrics.com/lyric/10115211
# Loaded https://www.lyrics.com/lyric/14903123
# Loaded https://www.lyrics.com/lyric/14294090
# Loaded https://www.lyrics.com/lyric/8509879
# Loaded https://www.lyrics.com/lyric/7463814
# Loaded https://www.lyrics.com/lyric/2635072
# Loaded https://www.lyrics.com/lyric/22202532
# Loaded https://www.lyrics.com/lyric/21544016
# Loaded https://www.lyrics.com/lyric/23263987
# Loaded https://www.lyrics.com/lyric/27240107
# Loaded https://www.lyrics.com/lyric/29582496
# Loaded https://www.lyrics.com/lyric/28245950
# Loaded https://www.lyrics.com/lyric/12160650
# Loaded https://www.lyrics.com/lyric/2125775
# Loaded https://www.lyrics.com/lyric/23211304
# Loaded https://www.lyrics.com/lyric/24622346
# Loaded https://www.lyrics.com/lyric/15553607
# Loaded https://www.lyrics.com/lyric/31444127
# Loaded https://www.lyrics.com/lyric/29568061
# Loaded https://www.lyrics.com/lyric/17985458
# Loaded https://www.lyrics.com/lyric/1225703
# Loaded https://www.lyrics.com/lyric/2353000
# Loaded https://www.lyrics.com/lyric/7062914
# Loaded https://www.lyrics.com/lyric/22604809
# Loaded https://www.lyrics.com/lyric/24991123
# Loaded https://www.lyrics.com/lyric/23886446
# Loaded https://www.lyrics.com/lyric/32435546
# Loaded https://www.lyrics.com/lyric/4574799
# Loaded https://www.lyrics.com/lyric/26427520
# Loaded https://www.lyrics.com/lyric/7732371
# Loaded https://www.lyrics.com/lyric/5711384
# Loaded https://www.lyrics.com/lyric/16235183
# Loaded https://www.lyrics.com/lyric/24154693
# Loaded https://www.lyrics.com/lyric/22070444
# Loaded https://www.lyrics.com/lyric/18985835
# Loaded https://www.lyrics.com/lyric/2954371
# Loaded https://www.lyrics.com/lyric/19282065
# Loaded https://www.lyrics.com/lyric/26781297
# Loaded https://www.lyrics.com/lyric/18249713
# Loaded https://www.lyrics.com/lyric/6812378
# Loaded https://www.lyrics.com/lyric/27550834
# Loaded https://www.lyrics.com/lyric/27259711
# Loaded https://www.lyrics.com/lyric/25802042
# Loaded https://www.lyrics.com/lyric/1022362
# Loaded https://www.lyrics.com/lyric/20341780
# Loaded https://www.lyrics.com/lyric/28488303
# Loaded https://www.lyrics.com/lyric/782274
# Loaded https://www.lyrics.com/lyric/13653921
# Loaded https://www.lyrics.com/lyric/19990453
# Loaded https://www.lyrics.com/lyric/14989634
# Loaded https://www.lyrics.com/lyric/27828896
# Loaded https://www.lyrics.com/lyric/27627559
# Loaded https://www.lyrics.com/lyric/9807039
# Loaded https://www.lyrics.com/lyric/18170999
# Loaded https://www.lyrics.com/lyric/26339201
# Loaded https://www.lyrics.com/lyric/31004485
# Loaded https://www.lyrics.com/lyric/26826220
# Loaded https://www.lyrics.com/lyric/4461988
# Loaded https://www.lyrics.com/lyric/1486435
# Loaded https://www.lyrics.com/lyric/26573171
# Loaded https://www.lyrics.com/lyric/11140851
# Loaded https://www.lyrics.com/lyric/30074427
# Loaded https://www.lyrics.com/lyric/17233180
# Loaded https://www.lyrics.com/lyric/26996023
# Loaded https://www.lyrics.com/lyric/839996
# Loaded https://www.lyrics.com/lyric/18122155
# Loaded https://www.lyrics.com/lyric/11224295
# Loaded https://www.lyrics.com/lyric/28691491
# Loaded https://www.lyrics.com/lyric/885638
# Loaded https://www.lyrics.com/lyric/6152694
# Loaded https://www.lyrics.com/lyric/752678
# Loaded https://www.lyrics.com/lyric/29148203
# Loaded https://www.lyrics.com/lyric/21382005
# Loaded https://www.lyrics.com/lyric/7436755
# Loaded https://www.lyrics.com/lyric/13465664
# Loaded https://www.lyrics.com/lyric/8747399
# Loaded https://www.lyrics.com/lyric/23215430
# Loaded https://www.lyrics.com/lyric/10188809
# Loaded https://www.lyrics.com/lyric/22638456
# Loaded https://www.lyrics.com/lyric/5640422
# Loaded https://www.lyrics.com/lyric/12188899
# Loaded https://www.lyrics.com/lyric/27328095
# Loaded https://www.lyrics.com/lyric/8479010
# Loaded https://www.lyrics.com/lyric/2091437
# Loaded https://www.lyrics.com/lyric/10991843
# Loaded https://www.lyrics.com/lyric/16932921
# Loaded https://www.lyrics.com/lyric/10230305
# Loaded https://www.lyrics.com/lyric/29266312
# Loaded https://www.lyrics.com/lyric/1754475
# Loaded https://www.lyrics.com/lyric/26653798
# Loaded https://www.lyrics.com/lyric/8386918
# Loaded https://www.lyrics.com/lyric/9308341
# Loaded https://www.lyrics.com/lyric/20496668
# Loaded https://www.lyrics.com/lyric/17930040
# Loaded https://www.lyrics.com/lyric/14165485
# Loaded https://www.lyrics.com/lyric/15923484
# Loaded https://www.lyrics.com/lyric/16400955
# Loaded https://www.lyrics.com/lyric/25985196
# Loaded https://www.lyrics.com/lyric/6295717
# Loaded https://www.lyrics.com/lyric/8363170
# Loaded https://www.lyrics.com/lyric/25973870
# Loaded https://www.lyrics.com/lyric/7602150
# Loaded https://www.lyrics.com/lyric/10689313
# Loaded https://www.lyrics.com/lyric/6134537
# Loaded https://www.lyrics.com/lyric/16746308
# Loaded https://www.lyrics.com/lyric/11860565
# Loaded https://www.lyrics.com/lyric/18021648
# Loaded https://www.lyrics.com/lyric/31170859
# Loaded https://www.lyrics.com/lyric/514936
# Loaded https://www.lyrics.com/lyric/672521
# Loaded https://www.lyrics.com/lyric/23445675
# Loaded https://www.lyrics.com/lyric/30690016
# Loaded https://www.lyrics.com/lyric/24040629
# Loaded https://www.lyrics.com/lyric/11748811
# Loaded https://www.lyrics.com/lyric/30763921
# Loaded https://www.lyrics.com/lyric/173987
# Loaded https://www.lyrics.com/lyric/30820984
# Loaded https://www.lyrics.com/lyric/26192661
# Loaded https://www.lyrics.com/lyric/1646897
# Loaded https://www.lyrics.com/lyric/22511283
# Loaded https://www.lyrics.com/lyric/10048987
# Loaded https://www.lyrics.com/lyric/21705955
# Loaded https://www.lyrics.com/lyric/25056663
# Loaded https://www.lyrics.com/lyric/5401960
# Loaded https://www.lyrics.com/lyric/10364606
# Loaded https://www.lyrics.com/lyric/721370
# Loaded https://www.lyrics.com/lyric/20907079
# Loaded https://www.lyrics.com/lyric/4146399
# Loaded https://www.lyrics.com/lyric/1703349
# Loaded https://www.lyrics.com/lyric/19768130
# Loaded https://www.lyrics.com/lyric/24982730
# Loaded https://www.lyrics.com/lyric/2825920
# Loaded https://www.lyrics.com/lyric/14615948
# Loaded https://www.lyrics.com/lyric/25928270
# Loaded https://www.lyrics.com/lyric/23162712
# Loaded https://www.lyrics.com/lyric/26741876
# Loaded https://www.lyrics.com/lyric/18369472
# Loaded https://www.lyrics.com/lyric/15601937
# Loaded https://www.lyrics.com/lyric/11680506
# Loaded https://www.lyrics.com/lyric/13466826
# Loaded https://www.lyrics.com/lyric/9847482
# Loaded https://www.lyrics.com/lyric/23169634
# Loaded https://www.lyrics.com/lyric/29520326
# Loaded https://www.lyrics.com/lyric/11742849
# Loaded https://www.lyrics.com/lyric/1676152
# Loaded https://www.lyrics.com/lyric/28909878
# Loaded https://www.lyrics.com/lyric/4636497
# Loaded https://www.lyrics.com/lyric/25576775
# Loaded https://www.lyrics.com/lyric/8995081
# Loaded https://www.lyrics.com/lyric/29493862
# Loaded https://www.lyrics.com/lyric/30556192
# Loaded https://www.lyrics.com/lyric/4845442
# Loaded https://www.lyrics.com/lyric/9444776
# Loaded https://www.lyrics.com/lyric/17670872
# Loaded https://www.lyrics.com/lyric/12963967
# Loaded https://www.lyrics.com/lyric/9610299
# Loaded https://www.lyrics.com/lyric/22904371
# Loaded https://www.lyrics.com/lyric/15229929
# Loaded https://www.lyrics.com/lyric/8351562
# Loaded https://www.lyrics.com/lyric/18443343
# Loaded https://www.lyrics.com/lyric/22025986
# Loaded https://www.lyrics.com/lyric/10055919
# Loaded https://www.lyrics.com/lyric/29598898
# Loaded https://www.lyrics.com/lyric/28763654
# Loaded https://www.lyrics.com/lyric/8110345
# Loaded https://www.lyrics.com/lyric/25359786
# Loaded https://www.lyrics.com/lyric/10248581
# Loaded https://www.lyrics.com/lyric/22823099
# Loaded https://www.lyrics.com/lyric/2838059
# Loaded https://www.lyrics.com/lyric/5997580
# Loaded https://www.lyrics.com/lyric/7674864
# Loaded https://www.lyrics.com/lyric/12266122
# Loaded https://www.lyrics.com/lyric/11275851
# Loaded https://www.lyrics.com/lyric/12741199
# Loaded https://www.lyrics.com/lyric/25530874
# Loaded https://www.lyrics.com/lyric/30234073
# Loaded https://www.lyrics.com/lyric/9577656
# Loaded https://www.lyrics.com/lyric/16950151
# Loaded https://www.lyrics.com/lyric/18195591
# Loaded https://www.lyrics.com/lyric/24997829
# Loaded https://www.lyrics.com/lyric/21531123
# Loaded https://www.lyrics.com/lyric/8993897
# Loaded https://www.lyrics.com/lyric/9563448
# Loaded https://www.lyrics.com/lyric/400066
# Loaded https://www.lyrics.com/lyric/26200758
# Loaded https://www.lyrics.com/lyric/3722440
# Loaded https://www.lyrics.com/lyric/10367820
# Loaded https://www.lyrics.com/lyric/14415732
# Loaded https://www.lyrics.com/lyric/23878092
# Loaded https://www.lyrics.com/lyric/32348407
# Loaded https://www.lyrics.com/lyric/15668340
# Loaded https://www.lyrics.com/lyric/1821439
# Loaded https://www.lyrics.com/lyric/32495544
# Loaded https://www.lyrics.com/lyric/1873790
# Loaded https://www.lyrics.com/lyric/30865601
# Loaded https://www.lyrics.com/lyric/2698856
# Loaded https://www.lyrics.com/lyric/19819619
# Loaded https://www.lyrics.com/lyric/5022349
# Loaded https://www.lyrics.com/lyric/18713889
# Loaded https://www.lyrics.com/lyric/6561059
# Loaded https://www.lyrics.com/lyric/66025
# Loaded https://www.lyrics.com/lyric/13423954
# Loaded https://www.lyrics.com/lyric/17844130
# Loaded https://www.lyrics.com/lyric/26593628
# Loaded https://www.lyrics.com/lyric/17240545
# Loaded https://www.lyrics.com/lyric/19174761
# Loaded https://www.lyrics.com/lyric/27170364
# Loaded https://www.lyrics.com/lyric/28922218
# Loaded https://www.lyrics.com/lyric/30263501
# Loaded https://www.lyrics.com/lyric/27267095
# Loaded https://www.lyrics.com/lyric/11807339
# Loaded https://www.lyrics.com/lyric/5182780
# Loaded https://www.lyrics.com/lyric/9647748
# Loaded https://www.lyrics.com/lyric/3201557
# Loaded https://www.lyrics.com/lyric/5343505
# Loaded https://www.lyrics.com/lyric/10737758
# Loaded https://www.lyrics.com/lyric/24618838
# Loaded https://www.lyrics.com/lyric/13253103
# Loaded https://www.lyrics.com/lyric/12715820
# Loaded https://www.lyrics.com/lyric/9275171
# Loaded https://www.lyrics.com/lyric/94655
# Loaded https://www.lyrics.com/lyric/27091284
# Loaded https://www.lyrics.com/lyric/7478206
# Loaded https://www.lyrics.com/lyric/19920653
# Loaded https://www.lyrics.com/lyric/25569570
# Loaded https://www.lyrics.com/lyric/20809842
# Loaded https://www.lyrics.com/lyric/28732825
# Loaded https://www.lyrics.com/lyric/18593336
# Loaded https://www.lyrics.com/lyric/26361999
# Loaded https://www.lyrics.com/lyric/32157598
# Loaded https://www.lyrics.com/lyric/22126334
# Loaded https://www.lyrics.com/lyric/28825634
# Loaded https://www.lyrics.com/lyric/23650216
# Loaded https://www.lyrics.com/lyric/12254610
# Loaded https://www.lyrics.com/lyric/7668126
# Loaded https://www.lyrics.com/lyric/9233191
# Loaded https://www.lyrics.com/lyric/17324180
# Loaded https://www.lyrics.com/lyric/24646314
# Loaded https://www.lyrics.com/lyric/12301728
# Loaded https://www.lyrics.com/lyric/1792884
# Loaded https://www.lyrics.com/lyric/20219645
# Loaded https://www.lyrics.com/lyric/23861693
# Loaded https://www.lyrics.com/lyric/5162918
# Loaded https://www.lyrics.com/lyric/21727475
# Loaded https://www.lyrics.com/lyric/21227476
# Loaded https://www.lyrics.com/lyric/1802719
# Loaded https://www.lyrics.com/lyric/27199313
# Loaded https://www.lyrics.com/lyric/14576610
# Loaded https://www.lyrics.com/lyric/25345333
# Loaded https://www.lyrics.com/lyric/7854622
# Loaded https://www.lyrics.com/lyric/3733566
# Loaded https://www.lyrics.com/lyric/19777926
# Loaded https://www.lyrics.com/lyric/30966339
# Loaded https://www.lyrics.com/lyric/11365970
# Loaded https://www.lyrics.com/lyric/27382093
# Loaded https://www.lyrics.com/lyric/639322
# Loaded https://www.lyrics.com/lyric/2532278
# Loaded https://www.lyrics.com/lyric/7169613
# Loaded https://www.lyrics.com/lyric/306014
# Loaded https://www.lyrics.com/lyric/30099145
# Loaded https://www.lyrics.com/lyric/30602460
# Loaded https://www.lyrics.com/lyric/15615380
# Loaded https://www.lyrics.com/lyric/8237751
# Loaded https://www.lyrics.com/lyric/12473323
# Loaded https://www.lyrics.com/lyric/17467351
# Loaded https://www.lyrics.com/lyric/23895010
# Loaded https://www.lyrics.com/lyric/23015322
# Loaded https://www.lyrics.com/lyric/1388187
# Loaded https://www.lyrics.com/lyric/30112667
# Loaded https://www.lyrics.com/lyric/10504084
# Loaded https://www.lyrics.com/lyric/29710250
# Loaded https://www.lyrics.com/lyric/32243099
# Loaded https://www.lyrics.com/lyric/25177253
# Loaded https://www.lyrics.com/lyric/17575361
# Loaded https://www.lyrics.com/lyric/5880092
# Loaded https://www.lyrics.com/lyric/15604081
# Loaded https://www.lyrics.com/lyric/20031575
# Loaded https://www.lyrics.com/lyric/15192178
# Loaded https://www.lyrics.com/lyric/18985252
# Loaded https://www.lyrics.com/lyric/18445081
# Loaded https://www.lyrics.com/lyric/2451307
# Loaded https://www.lyrics.com/lyric/17485741
# Loaded https://www.lyrics.com/lyric/25239910
# Loaded https://www.lyrics.com/lyric/6616958
# Loaded https://www.lyrics.com/lyric/21322622
# Loaded https://www.lyrics.com/lyric/1955728
# Loaded https://www.lyrics.com/lyric/15399684
# Loaded https://www.lyrics.com/lyric/4719805
# Loaded https://www.lyrics.com/lyric/27487598
# Loaded https://www.lyrics.com/lyric/26035042
# Loaded https://www.lyrics.com/lyric/9358318
# Loaded https://www.lyrics.com/lyric/1567474
# Loaded https://www.lyrics.com/lyric/10484049
# Loaded https://www.lyrics.com/lyric/15056636
# Loaded https://www.lyrics.com/lyric/22141299
# Loaded https://www.lyrics.com/lyric/712184
# Loaded https://www.lyrics.com/lyric/501942
# Loaded https://www.lyrics.com/lyric/21014566
# Loaded https://www.lyrics.com/lyric/13127806
# Loaded https://www.lyrics.com/lyric/30264374
# Loaded https://www.lyrics.com/lyric/26641259
# Loaded https://www.lyrics.com/lyric/24654272
# Loaded https://www.lyrics.com/lyric/312609
# Loaded https://www.lyrics.com/lyric/30588462
# Loaded https://www.lyrics.com/lyric/16452197
# Loaded https://www.lyrics.com/lyric/22134259
# Loaded https://www.lyrics.com/lyric/23517196
# Loaded https://www.lyrics.com/lyric/4852578
# Loaded https://www.lyrics.com/lyric/29063479
# Loaded https://www.lyrics.com/lyric/15566758
# Loaded https://www.lyrics.com/lyric/17460856
# Loaded https://www.lyrics.com/lyric/19316881
# Loaded https://www.lyrics.com/lyric/25116024
# Loaded https://www.lyrics.com/lyric/15951967
# Loaded https://www.lyrics.com/lyric/23654155
# Loaded https://www.lyrics.com/lyric/1895001
# Loaded https://www.lyrics.com/lyric/11141626
# Loaded https://www.lyrics.com/lyric/16381724
# Loaded https://www.lyrics.com/lyric/8445384
# Loaded https://www.lyrics.com/lyric/22476589
# Loaded https://www.lyrics.com/lyric/18984313
# Loaded https://www.lyrics.com/lyric/4166878
# Loaded https://www.lyrics.com/lyric/17594662
# Loaded https://www.lyrics.com/lyric/26724508
# Loaded https://www.lyrics.com/lyric/18924039
# Loaded https://www.lyrics.com/lyric/4080006
# Loaded https://www.lyrics.com/lyric/29141
# Loaded https://www.lyrics.com/lyric/1892883
# Loaded https://www.lyrics.com/lyric/5930348
# Loaded https://www.lyrics.com/lyric/28173968
# Loaded https://www.lyrics.com/lyric/32365609
# Loaded https://www.lyrics.com/lyric/21625577
# Loaded https://www.lyrics.com/lyric/31680613
# Loaded https://www.lyrics.com/lyric/5820571
# Loaded https://www.lyrics.com/lyric/1985745
# Loaded https://www.lyrics.com/lyric/2582916
# Loaded https://www.lyrics.com/lyric/27047835
# Loaded https://www.lyrics.com/lyric/31009963
# Loaded https://www.lyrics.com/lyric/20224135
# Loaded https://www.lyrics.com/lyric/25067109
# Loaded https://www.lyrics.com/lyric/32352899
# Loaded https://www.lyrics.com/lyric/32091283
# Loaded https://www.lyrics.com/lyric/15200367
# 1000

# %%
print(collection[0])
# Out:
# Song Angel by Anita Baker

# %% [markdown]
# # 3. Inverted index (old)
# You will work with the boolean search model. Construct a dictionary which maps words to the postings.

# %%
def make_index(collection):
    inverted_index = {}
    for song in collection:
        # Clean the text, then add words to the index
        clean = preprocess(song.text)
        for word in clean:
            if not word in inverted_index:
                inverted_index[word] = {song} # If we haven't encountered the word previously - create set with it
            else:
                inverted_index[word].add(song) # Otherwise add to the set
    return inverted_index

# %%
# index = make_index(collection)
# print(index['november'])

# %% [markdown]
# # 4. Query processing (old)
#
# Using given search query, find all relevant documents. In binary model the relevant document is the one which contains all words from the query.
#
# Return the list of relevant documents indexes.

# %%
def search(index, query):
    # Get clean query
    clean_query = preprocess(query)
    if not clean_query:
        return {} # Query empty - return nothing
    else:
        # Get first set of documents
        relevant_documents = index[clean_query[0]].copy()
    for word in clean_query[1:]:
        # Intersect with the rest of set of document in index for each word in the query
        relevant_documents &= index[word] 
    return list(relevant_documents)

# %%
# query = 'sound around' # change for something else if you are searching song lyrics
# relevant = search(index, query)
# print(len(relevant))
# relevant[0]

# %% [markdown]
# # Prefix tree

# %% [markdown]
# Prefix tree that we will use to create index

# %%
class PrefixT: 
    def __init__(self, letter, parent=None):
        self.children = {} # Children - dictionary that maps next letter to the parent
        self.l: str = letter # The content of the node, letter
        self.parent = parent # Parent of the node

    def add_word(self, word: str):
        word = word+"@" # @ will indicate end of the word
        cur_tree = self
        
        # Iteratively add every letter to the tree while going deeper
        for letter in word:
            if not letter in cur_tree.children:
                cur_tree.children[letter] = PrefixT(letter, cur_tree)
            cur_tree = cur_tree.children[letter]

    def get_words(self, cur_word=''):
        # Gets all possible words from self node, doesn't return prefix, DFS
        cur_word += self.l
        if not self.children:
            return {cur_word}
        to_return = set()
        for tree in self.children.values():
            to_return = to_return.union(tree.get_words(cur_word))
        return to_return

    def prefix(self):
        # Returns prefix (with itself) of the words 
        prefix = self.l
        if self.parent is None:
            return prefix
        else:
            return self.parent.prefix() + prefix

    def __eq__(self, other):
        return self.l == other.l

    def __hash__(self):
        return self.l.__hash__()

    def __str__(self):
        return f"PrefixT({self.l})"

    def __repr__(self):
        return self.__str__()

    def __getitem__(self, item):
        # Finds the string in the current node with name "item"
        cur_child = self
        if len(item) == 1:
            if item in self.children:
                return self.children[item]
            else:
                return None
        for i in item:
            if not i in cur_child.children:
                return None
            cur_child = cur_child[i]
        return cur_child

# %%
def get_rotations(word):
    # Performs all rotations 
    wordword = word+word
    to_return = set()
    length = len(word)
    
    for i in range(length):
        to_return.add(wordword[i:length+i]) # slide over the wordword and get all rotations
        
    return to_return

# %% [markdown]
# # Soundex index

# %% [markdown]
# Soundex algorithm that makes a soundex to be indexed given a word

# %%
soundex_dictionary = {'a':0, 'e':0, 'i':0, 'o':0, 'u':0, 'y':0, 'h':0, 'w':0,
                      'b':1, 'f':1, 'p':1, 'v':1,
                      'c':2, 'g':2, 'j':2, 'k':2, 'q':2, 's':2, 'x':2, 'z':2,
                      'd':3, 't':3, 'l':4, 'm':5, 'n':5, 'r':6}

def make_soundex(word):
    soundex = word[0].upper() # take the first letter
    
    for letter in word[1:]:
        if len(soundex) == 4: # Stop at 4 letters or when the word have been exhauseted
            break
        number = soundex_dictionary[letter]
        
        # If the number is not 0 - add it to the soundex
        if number and str(number) not in soundex:
            soundex += str(number)
    # If the length of the word isn't 4 - fill it with 0s
    if len(soundex) != 4:
        soundex +='0'*(4-len(soundex))
    return soundex

# %% [markdown]
# # Levenshtein Distance

# %% [markdown]
# Computes the distance between 2 words

# %%
def levenshtein_distance(word1, word2):
    matrix = np.zeros((len(word1)+1, len(word2)+1)) # Initial matrix
    
    # Fill the corner with ranges of the words
    for i in range(len(word2)+1):
        matrix[0][i] = i
    for i in range(len(word1)+1):
        matrix[i][0] = i
    
    # Go over matrix and compute the distance
    for i in range(1, len(word1)+1):
        for j in range(1, len(word2)+1):
            matrix[i][j] = min(matrix[i-1][j-1] + (1 if word1[i-1] != word2[j-1] else 0),
                               matrix[i][j-1]+1, matrix[i-1][j]+1)
    # Take lower right corner - this is an answer
    return matrix[-1][-1]

# %% [markdown]
# # Make Indexes

# %%
text = """Borrowed from Latin per sē (“by itself”), from per (“by, through”) and sē (“itself, himself, herself, themselves”)"""

def preprocess(text):
    # Now returns two lists
    # First one with lemmatization
    # Other one without lemmatization
    text = tokenize(normalize(text))
    return remove_stop_word(lemmatization(text)), remove_stop_word(text) # All-in-one

# %%
preprocess(text)
# Out:
# (['borrowed', 'latin', 'per', 'per'], ['borrowed', 'latin', 'per', 'per'])

# %%
def make_indexes(collection):
    inverted_index = {}
    soundex_index = {}
    prefix_tree = PrefixT('')
    for song in collection:
        
        # Clean the text, then add words to the index
        clean, unlemmatized = preprocess(song.text)
        
        for word in clean:
            if not word in inverted_index:
                inverted_index[word] = {song} # If we haven't encountered the word previously - create set with it
            else:
                inverted_index[word].add(song) # Otherwise add to the set
        
        # Now go over unlemmatized part
        for word in unlemmatized:
            
            rotations = get_rotations(word+"$")
            
            # Add rotations to the prefix tree
            for rot in rotations:
                prefix_tree.add_word(rot)
            sound = make_soundex(word)
            
            # Add sounds to the soundex index
            if not sound in soundex_index:
                soundex_index[sound] = set([word])
            else:
                soundex_index[sound].add(word)
    
    return inverted_index, soundex_index, prefix_tree

# %%
inverted_index, soundex_index, prefix_tree = make_indexes(collection)

# %% [markdown]
# # Query Preprocessing and Search

# %% [markdown]
# There will be two steps
# 1. Cleaning initial query given by user, creating a new query
# 2. Use cleaned query in the search

# %%
def rotate_back(word):
    # Rotate the word back to the original position and clean the end notifier (@)
    
    while word[-1] != "$":
        word = word[-1]+word[:-1]
        
    return word.replace("@", "")[:-1]

def wildcard_query(word, prefix_tree):
    # Perform wildcard querying (supports only single *)
    if not "*" in word:
        return None
    
    word = word+"$"
    
    # Rotate until * is in the end
    while word[-1] != "*":
        word = word[-1]+word[:-1]
    
    # Find possible words in the prefix tree (removing *)
    found = prefix_tree[word[:-1]].get_words()
    
    # Process answer
    words = list(
        map(
            lambda x: rotate_back(word[:-2]+x),
            list(found)
        )
    )
    return words

def query_prettifier(query):
    # Prettify query for the print
    query = query.copy()
    for i in range(len(query)):
        if isinstance(query[i], list):
            query[i] = f'({" || ".join(query[i])})'
    return " && ".join(query)



def parse_query(inverted_index, soundex_index, prefix_tree, query):
    # Clean the query
    clean_query = remove_stop_word(tokenize(normalize(query, True)))
    
    if not clean_query:
        return [] # Query empty - return nothing
    new_query = []
    
    for word in clean_query:
        # If the word in the index - just add it to the query
        if word in inverted_index:
            new_query.append(word)
        # If the word has *, then perform wildcard query
        # Then lemmatize the result (as we will search in the inverted_index) and remove stop words
        elif '*' in word:
            items = wildcard_query(word, prefix_tree)
            items = remove_stop_word(lemmatization(items))
            new_query.append(list(set(items)))
            
        # If this word is still unknown - try to fix it
        # find it in soundex_index the query, compute the distance for all words found and take ones with
        # minimum distance
        else:
            
            soundex = make_soundex(word)
            if soundex in soundex_index:
                sound_words = soundex_index[soundex]
                distances = []
                
                for w in sound_words:
                    distances.append(levenshtein_distance(w,word))
                
                minimum = min(distances)
                final = [sound_word for sound_word, dis in zip(sound_words, distances) if dis == minimum]
                 # Lemmatize words and remove stop words (as we will use inverted_index)
                final = remove_stop_word(lemmatization(final))
                new_query.append(list(set(final)))
            else:
                return [] # No docs with this word
    
    if not new_query:
        return [] # Empty query
    print(f"Query was perceived as: {query_prettifier(new_query)}")
    
    # Sort by strings first - lists last
    new_query = sorted(new_query, key=lambda x: isinstance(x, list))
    return new_query


def search(inverted_index, query):
    # The query has the following structure:
    # It is a list of lists or string
    # If an element of the query is a list - all docs of items of this list are OR'ed
    # And then they will be AND'ed with each other
    if not query:
        return {}
    docs = set()
    
    # Take the initial docs set
    if isinstance(new_query[0], list):
        # If the value is a list - take OR over all values
        l = new_query[0]
        docs = inverted_index[l[0]].copy()
        
        for i in l[1:]:
            docs |= inverted_index[i]
    else:
        # If the value is a string -just take it
        docs = inverted_index[new_query[0]].copy()
        
    for words in new_query[1:]:
        # Now go over remaining items
        if isinstance(words, list):
            # If the list - OR it's items and then AND with the current docs
            new_docs = inverted_index[words[0]].copy()
            for word in words[1:]:
                new_docs |= inverted_index[word]
            docs &= new_docs
            
        else:
            # If string - just AND with the current docs
            docs &=inverted_index[words]
    return docs

# %% [markdown]
# # Test

# %%
query = "heer sound*"
new_query = parse_query(inverted_index, soundex_index, prefix_tree, query)
docs = search(inverted_index, new_query)
docs
# Out:
# Query was perceived as: (hear || hier) && (sound || sounding)
# {Song Animals by Maroon 5,
#  Song Chin Up, Cheer Up by Ryan Adams,
#  Song Feel the Vibe by The Pyschotic Neurotics, Diamond D,
#  Song Goofus by Slim Lamar & His Southerners,
#  Song If You Know What I Mean by Neil Diamond,
#  Song Lied Vom Leben by Xavas,
#  Song Life by Chocolate Genius,
#  Song New Kid in Town by Pickin' On,
#  Song O by Omarion,
#  Song Once in a Lifetime by DJ Baby Anne, Wolfsheim,
#  Song Pirate Jenny [Live] by Nina Simone,
#  Song Say Anything by X Japan,
#  Song World of Entertainment (Woe Is Me) by Jurassic 5}

# %% [markdown]
# The values will not be the same with just "hear" and "sound"

# %%
hear_sound = inverted_index['hear'] & inverted_index['sound']
hear_sound == docs
# Out:
# False

# %% [markdown]
# As there is a song with word "hier" (German?) in the index

# %%
hear_sound | (inverted_index['hier'] & inverted_index['sound']) == docs
# Out:
# True

# %% [markdown]
# Another test

# %%
query = "heer s*nd"
new_query = parse_query(inverted_index, soundex_index, prefix_tree, query)
docs = search(inverted_index, new_query)
docs
# Out:
# Query was perceived as: (hear || hier) && (sound || southland || surprend || sand || sind || second || surround || stand || send || spend)
# {Song Animals by Maroon 5,
#  Song Burn by Dirty Halo,
#  Song Chin Up, Cheer Up by Ryan Adams,
#  Song Conflict by Royal Flush, Wastlanz,
#  Song Cornbread by Freestyle Fellowship,
#  Song Down by Low,
#  Song Feel the Vibe by The Pyschotic Neurotics, Diamond D,
#  Song Give It Away by Gaither Vocal Band,
#  Song Goofus by Slim Lamar & His Southerners,
#  Song Guitar Town by Steve Earle,
#  Song If You Know What I Mean by Neil Diamond,
#  Song It's up to You by The Specials,
#  Song Kalamazoo by The Andrews Sisters, Glenn Miller,
#  Song Lied Vom Leben by Xavas,
#  Song Life by Chocolate Genius,
#  Song Money Fi Spend by Vybz Kartel,
#  Song New Kid in Town by Pickin' On,
#  Song O Holy Night by Mormon Tabernacle Choir,
#  Song O by Omarion,
#  Song Once in a Lifetime by DJ Baby Anne, Wolfsheim,
#  Song Perfekte Welle [Album Version] by Juli,
#  Song Pirate Jenny [Live] by Nina Simone,
#  Song Public Servant by Todd Rundgren,
#  Song Say Anything by X Japan,
#  Song Shake Some Action by Flamin' Groovies,
#  Song Spend Some Time by Eminem, 50 Cent, Obie Trice, Stat Quo,
#  Song Stand Back by Stevie Nicks,
#  Song Ti Amo by Howard Carpendale,
#  Song Warum by Juli,
#  Song World of Entertainment (Woe Is Me) by Jurassic 5}
